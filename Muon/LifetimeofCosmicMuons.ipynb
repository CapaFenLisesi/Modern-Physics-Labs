# %%
import qexpy as q
import numpy as np

# %%
q.plot_engine = "mpl"

# %%
from matplotlib import pyplot;
from pylab import genfromtxt;

# %%
muonData = genfromtxt("MuonSimpleData.txt")

# %%
print(muonData)
# Out:
# [  0.   0.  10. ...,  14.  12.   9.]

# %%
muonCount = q.MeasurementArray(muonData,error=[1],name="Muon Count", units="N")

# %%
bins = q.MeasurementArray(np.linspace(0,len(muonData)*0.0222,len(muonData)),error=[0.0003],name="Lifetime",units="us")

# %%
figure = q.MakePlot(bins,muonCount)
figure.show()

# %% [markdown]
# para[0] = No, para[1] = 1/T, para[2] = C

# %%
def muonModel(t, *para):
    return para[0]*np.exp(-t*para[1])+para[2]

# %%
figure.fit(muonModel, fitcolor="blue", parguess=[4,0.01,25]);
# Out:
# -----------------Fit results-------------------
# Fit of  dataset3  to  custom
# Fit parameters:
# dataset3_custom_fit0_fitpars_par0 = 157 +/- 2,
# dataset3_custom_fit0_fitpars_par1 = 0.363 +/- 0.006,
# dataset3_custom_fit0_fitpars_par2 = 13.3 +/- 0.2
#
# Correlation matrix:
# [[ 1.     0.653 -0.002]
#  [ 0.653  1.     0.371]
#  [-0.002  0.371  1.   ]]
#
# chi2/ndof = 178123.72/2044
# ---------------End fit results----------------

# %%
figure.show()

# %%
T = 1/0.363
print(T)
# Out:
# 2.7548209366391188
